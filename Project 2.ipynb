# %% [raw]
# Project 2

# %%
import pandas as pd

# %%
df=pd.read_csv("Multi.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
x=df[["area","bedrooms","age"]]

# %%
x
# Out:
#    area  bedrooms  age
# 0  2600         3   20
# 1  3000         4   15
# 2  3200         3   18
# 3  3600         3   30
# 4  4000         5    8

# %%
y=df.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
model.intercept_
# Out:
# np.float64(383724.9999999998)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict([[5000,3,5]])
# Out:
# array([957775.])

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
import pickle

# %%
with open("house_price_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in c:\users\visha\appdata\roaming\python\python313\site-packages (1.48.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: packaging<26,>=20 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\visha\appdata\roaming\python\python313\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\visha\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\visha\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.2.0)
# Requirement already satisfied: colorama in c:\users\visha\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\visha\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\visha\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\visha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\visha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\visha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\visha\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\visha\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\visha\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\visha\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\visha\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
st
# Out:
# <module 'streamlit' from 'C:\\Users\\visha\\AppData\\Roaming\\Python\\Python313\\site-packages\\streamlit\\__init__.py'>
